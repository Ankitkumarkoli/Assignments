# %% [markdown]
# # Q1. Explain GET and POST methods.

# %%
'''
GET = It is used to send the data by using URL.

POST = It is used to send the data by using body of the form. 
'''
# Out:
# '\nGET = It is used to send the data by using URL.\n\nPOST = It is used to send the data by using body of the form. \n'

# %% [markdown]
# # Q2. Why is request used in Flask?

# %%
# The request used in flask allows you to represent incoming HTTP requests

# %% [markdown]
# # Q3. Why is redirect() used in Flask?

# %%
# Used to allow developers to redirect users to a specific URL

# %% [markdown]
# # Q4. What are templates in Flask? Why is the render_template() function used?

# %%
# Templates are the HTML, CSS, JS files that are used to display content on the website, Templates beautify the web pages and make them presentable.

# render_template is used to generate output from a template file based on the Jinja2 engine that is found in the application templates folder.

# %% [markdown]
# # Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
'''
from flask import Flask,render_template , request , jsonify

app = Flask(__name__)

@app.route('/', methods = ['GET','POST'])
def home_page():
    return render_template('index.html')

@app.route('/math', methods = ['POST'])
def math_operation():
    if(request.method == 'POST'):
        ops = request.form['operation']
        ek1 = int(request.form['ek1'])
        do2 = int(request.form['do2'])
        if(ops == 'add'):
            r = ek1 + do2
            result = 'The sum of' + str(ek1) + 'and' + str(do2) + "is" + str(r)
       
        if(ops == 'subtract'):
            r = ek1 - do2
            result = 'The subtract of' + str(ek1) + 'and' + str(do2) + "is" + str(r)
        
        if(ops == 'multiply'):
            r = ek1 * do2
            result = 'The multiply of' + str(ek1) + 'and' + str(do2) + "is" + str(r)

        if(ops == 'divide'):
            r = ek1/do2
            result = 'The divide of' + str(ek1) + 'and' + str(do2) + "is" + str(r)
        return render_template('results.html',result = result)

@app.route('/selmonbhai_postman', methods = ['POST'])
def math_operation1():
    if(request.method == 'POST'):
        ops = request.json['operation']
        ek1 = int(request.json['ek1'])
        do2 = int(request.json['do2'])
        if(ops == 'add'):
            r = ek1 + do2
            result = 'Sum of' + str(ek1) + 'and' + str(do2) + "is" + str(r)
       
        if(ops == 'subtract'):
            r = ek1 - do2
            result = 'Subtract of' + str(ek1) + 'and' + str(do2) + "is" + str(r)
        
        if(ops == 'multiply'):
            r = ek1 * do2
            result = 'Multiply of' + str(ek1) + 'and' + str(do2) + "is" + str(r)

        if(ops == 'divide'):
            r = ek1/do2
            result = 'Divide of' + str(ek1) + 'and' + str(do2) + "is" + str(r)
        return jsonify(result)

if __name__=="__main__":
    app.run(host="0.0.0.0")

'''
# Out:
# '\nfrom flask import Flask,render_template , request , jsonify\n\napp = Flask(__name__)\n\n@app.route(\'/\', methods = [\'GET\',\'POST\'])\ndef home_page():\n    return render_template(\'index.html\')\n\n@app.route(\'/math\', methods = [\'POST\'])\ndef math_operation():\n    if(request.method == \'POST\'):\n        ops = request.form[\'operation\']\n        ek1 = int(request.form[\'ek1\'])\n        do2 = int(request.form[\'do2\'])\n        if(ops == \'add\'):\n            r = ek1 + do2\n            result = \'The sum of\' + str(ek1) + \'and\' + str(do2) + "is" + str(r)\n       \n        if(ops == \'subtract\'):\n            r = ek1 - do2\n            result = \'The subtract of\' + str(ek1) + \'and\' + str(do2) + "is" + str(r)\n        \n        if(ops == \'multiply\'):\n            r = ek1 * do2\n            result = \'The multiply of\' + str(ek1) + \'and\' + str(do2) + "is" + str(r)\n\n        if(ops == \'divide\'):\n            r = ek1/do2\n            result = \'The divide of\' + 
# ...

# %% [markdown]
# ![Screenshot 2023-03-04 203027.png](attachment:86b785c6-fdcc-4a9f-bce7-02b4a5cccef3.png)
